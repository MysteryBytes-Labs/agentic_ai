# %% [markdown]
# # Welcome to first step of your learning journey of creating and deploying AGENTIC_AI.
# # Lab 1 — Initial Setup and Ollama Chat Setup with Qwen3
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 250px; height: 150px; vertical-align: middle;">
#             <img src="../assets/logo.png" width="250" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Objective</h2>
#             <span style="color:#ff7800;">- Run ChatGPT-level AI locally <br>
# - Windows/macOS/Linux<br>
# - 100% Free & Private<br>
# - Qwen3 chat example
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## How to Use This Notebook
# Follow along step by step. Run each code cell in order and compare your output to the expected behavior.
#
# 1. Start the Ollama server locally before running the first code cell.
# 2. Run the streaming request cell to see token-by-token output.
# 3. Switch to the OpenAI-compatible chat example and review the message format.
# 4. Re-run with your own prompt to confirm the pipeline works end to end.

# %%
import os
import json
from openai import OpenAI
from IPython.display import Markdown, display
import requests
import json

# %%
resp = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "qwen3:8b",
        "prompt": "Write a short Python function that reverses a string."
    },
    stream=True,
)

for line in resp.iter_lines():
    if not line:
        continue
    data = json.loads(line)
    print(data.get("response", ""), end="", flush=True)
# Out:
# Here's a concise and efficient Python function that reverses a string using Python's slicing feature:
#
# ```python
# def reverse_string(s):
#     return s[::-1]
# ```
#
# ---
#
# ### Explanation:
# - The function `reverse_string` takes a single argument `s`, which is expected to be a string.
# - The slicing operation `s[::-1]` creates a new string by iterating from the end of the original string to the beginning, effectively reversing it.
# - This method is both simple and efficient, with a time complexity of **O(n)**, where `n` is the length of the string.
# - It handles edge cases like empty strings or single-character strings naturally.
#
# ---
#
# ### Example Usage:
# ```python
# print(reverse_string("hello"))  # Output: "olleh"
# print(reverse_string(""))        # Output: ""
# print(reverse_string("a"))       # Output: "a"
# ```
#
# This implementation is ideal for most use cases where string reversal is required.

# %%
request = "Compare the population of New York and Los Angeles ."
request += " Provide the answer in a markdown table format."
message = [
    {"role": "system", "content" : "You are a helpful assistant."},
    {"role": "user", "content" : request}
]
answers = []

# %%
print (request)
# Out:
# Compare the population of New York and Los Angeles . Provide the answer in a markdown table format.

# %%
ollama = OpenAI(base_url="http://localhost:11434/v1", api_key='ollama')
model_name = "qwen3:8b"
response = ollama.chat.completions.create(
    model=model_name,
    messages=message
)

answers = response.choices[0].message.content

print(answers)
# Out:
# | **City**         | **Population (2023 Estimate)** | **Additional Notes**                              |
# |------------------|-------------------------------|--------------------------------------------------|
# | New York City    | ~8.3 million                  | Most populous city in the United States.         |
# | Los Angeles      | ~3.9 million                  | Second-most populous city in the United States.  |
#
# **Note:** Population figures are approximate and based on recent estimates. Metropolitan areas (e.g., New York City and Los Angeles metropolitan regions) would have significantly larger populations.

# %%
display(Markdown(answers))
# Out:
# | **City**         | **Population (2023 Estimate)** | **Additional Notes**                              |
# |------------------|-------------------------------|--------------------------------------------------|
# | New York City    | ~8.3 million                  | Most populous city in the United States.         |
# | Los Angeles      | ~3.9 million                  | Second-most populous city in the United States.  |
#
# **Note:** Population figures are approximate and based on recent estimates. Metropolitan areas (e.g., New York City and Los Angeles metropolitan regions) would have significantly larger populations.
